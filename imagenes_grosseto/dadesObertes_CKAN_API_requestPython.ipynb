# %%
# Hacer la petición HTTP usando la libreria http.client de Python:

#!/usr/bin/env python

# %%
# Figura 1 – Listar todos los temas o conjunto de datos en dadesobertes.gva.es

import http.client
import json
import pprint

conn = http.client.HTTPSConnection("dadesobertes.gva.es")
payload = ''
headers = {
  'Cookie': 'NSC_mc1_qsf_usb_dlbo_80=ffffffffaf1398f045525d5f4f58455e445a4a423660'
}

# Hacer la petición HTTP.
conn.request("GET", "/api/3/action/package_list", payload, headers)
response = conn.getresponse()

assert response.code == 200

# Usar el módulo JSON para cargar la respuesta de CKAN en un diccionario.
response_dict = json.loads(response.read())

# Comprobar el contenido de la respuesta.
assert response_dict['success'] is True
result = response_dict['result']
pprint.pprint(result)
# Out:
# ['academias-nauticas-de-la-comunitat-valenciana',
#  'accesibilidad-de-acuiferos-coput-1995',
#  'afecciones-por-carreteras-de-la-comunitat-valenciana-coput-1998',
#  'afecciones-por-carreteras-del-estado-coput-1998',
#  'agr-obs-pre-magatzem',
#  'agr-obs-pre-origen',
#  'ambito-del-plan-de-prevencion-de-incendios-de-la-rv-de-caza-de-la-muela-de-cortes',
#  'ambito-ley-de-la-huerta',
#  'ambito-restringido-de-reservas-de-fauna-de-la-comunitat-valenciana',
#  'ambitos-territoriales-de-la-estrategia-territorial-de-la-cv',
#  'aprovechamiento-de-rocas-industriales-poligonos-coput-1991',
#  'aprovechamiento-de-rocas-industriales-puntuales-coput-1991',
#  'aptitud-del-territorio-clima-y-suelo-para-la-realizacion-de-plantaciones-truferas-patfor',
#  'aptitud-del-territorio-para-la-produccion-optima-de-nogal-patfor',
#  'area-de-influencia-puntos-de-agua-de-carga-aerea-de-los-planes-de-prevencion-de-incendios-fores',
# ...

# %%
# Figura 2 – Temas o conjunto de datos agrupados en dadesobertes.gva.es

import http.client

conn = http.client.HTTPSConnection("dadesobertes.gva.es")
payload = ''
headers = {
  'Cookie': 'NSC_mc1_qsf_usb_dlbo_80=ffffffffaf1398f045525d5f4f58455e445a4a423660'
}

# Hacer la petición HTTP.
conn.request("GET", "/api/3/action/group_list", payload, headers)
response = conn.getresponse()

assert response.code == 200

# Usar el módulo JSON para cargar la respuesta de CKAN en un diccionario.
response_dict = json.loads(response.read())

# Comprobar el contenido de la respuesta.
assert response_dict['success'] is True
result = response_dict['result']
pprint.pprint(result)
# Out:
# ['ciencia-tecnologia',
#  'comercio',
#  'cultura-ocio',
#  'demografia',
#  'deporte',
#  'economia',
#  'educacion',
#  'empleo',
#  'energia',
#  'hacienda',
#  'industria',
#  'legislacion-justicia',
#  'medio-ambiente',
#  'medio-rural-pesca',
#  'salud',
#  'sector-publico',
#  'seguridad',
#  'sociedad-bienestar',
#  'transporte',
#  'turismo',
#  'urbanismo-infraestructuras',
#  'vivienda']

# %%
import http.client
import json

conn = http.client.HTTPSConnection("dadesobertes.gva.es")
payload = ''
headers = {
 'Cookie': 'NSC_mc1_qsf_usb_dlbo_80=ffffffffaf1398f045525d5f4f58455e445a4a423660'
}

# Modificar la URL para acceder a los datos del grupo 'medio-ambiente'
conn.request("GET", "/api/3/action/group_show?id=medio-ambiente", payload, headers)
response = conn.getresponse()

assert response.code == 200

# Cargar la respuesta en un diccionario
response_dict = json.loads(response.read())

# Verificar el contenido de la respuesta
assert response_dict['success'] is True
result = response_dict['result']
pprint.pprint(result)
# Out:
# {'approval_status': 'approved',
#  'created': '2019-05-16T09:40:32.033344',
#  'description': '',
#  'display_name': 'Medio ambiente',
#  'extras': [],
#  'groups': [],
#  'id': 'a3fbb015-cf22-4ebe-b4c3-84590c9e3143',
#  'image_display_url': 'https://dadesobertes.gva.es/uploads/group/2022-05-11-101604.913439medio-ambiente.png',
#  'image_url': '2022-05-11-101604.913439medio-ambiente.png',
#  'is_organization': False,
#  'name': 'medio-ambiente',
#  'num_followers': 0,
#  'package_count': 1444,
#  'revision_id': 'fee4a658-7afd-440a-9aa2-9a76c456a0cc',
#  'state': 'active',
#  'tags': [],
#  'title': 'Medio ambiente',
#  'type': 'group'}

# %%
import http.client
import json

conn = http.client.HTTPSConnection("dadesobertes.gva.es")
payload = ''
headers = {
 'Cookie': 'NSC_mc1_qsf_usb_dlbo_80=ffffffffaf1398f045525d5f4f58455e445a4a423660'
}

# Realizar una solicitud para listar los paquetes dentro del grupo 'medio-ambiente'
conn.request("GET", "/api/3/action/package_search?q=medio-ambiente", payload, headers)
response = conn.getresponse()

assert response.code == 200

# Cargar la respuesta en un diccionario
response_dict = json.loads(response.read())

# Verificar el contenido de la respuesta
assert response_dict['success'] is True
result = response_dict['result']
pprint.pprint(result)
# Out:
# {'count': 849,
#  'facets': {},
#  'results': [{'creator_user_id': 'e3846494-e111-48e9-adeb-c27b3e75dc41',
#               'extras': [{'key': 'access_constraints',
#                           'value': '["No hay limitaciones"]'},
#                          {'key': 'bbox-east-long', 'value': '0.695'},
#                          {'key': 'bbox-north-lat', 'value': '40.789'},
#                          {'key': 'bbox-south-lat', 'value': '37.844'},
#                          {'key': 'bbox-west-long', 'value': '-1.528'},
#                          {'key': 'contact-email',
#                           'value': 'responde_icv@gva.es'},
#                          {'key': 'coupled-resource', 'value': '[]'},
#                          {'key': 'dataset-reference-date',
#                           'value': '[{"type": "creation", "value": '
#                                    '"2020-12-02"}]'},
#                          {'key': 'frequency-of-update', 'value': ''},
# ...

# %%
import http.client
import json

conn = http.client.HTTPSConnection("dadesobertes.gva.es")
payload = ''
headers = {
 'Cookie': 'NSC_mc1_qsf_usb_dlbo_80=ffffffffaf1398f045525d5f4f58455e445a4a423660'
}

# Realizar una solicitud para listar los paquetes dentro del grupo 'medio-ambiente'
conn.request("GET", "/api/3/action/package_show?id=zonas-de-calidad-del-aire", payload, headers)
response = conn.getresponse()

assert response.code == 200

# Cargar la respuesta en un diccionario
response_dict = json.loads(response.read())

# Verificar el contenido de la respuesta
assert response_dict['success'] is True
result = response_dict['result']
pprint.pprint(result)
# Out:
# {'archiver': {'is_broken': False,
#               'reason': '',
#               'status': 'Archived successfully',
#               'status_id': 0},
#  'creator_user_id': 'e3846494-e111-48e9-adeb-c27b3e75dc41',
#  'extras': [{'key': 'access_constraints',
#              'value': '["Sin limitaciones al acceso p\\u00fablico"]'},
#             {'key': 'bbox-east-long', 'value': '0.740218'},
#             {'key': 'bbox-north-lat', 'value': '40.815079'},
#             {'key': 'bbox-south-lat', 'value': '37.81157'},
#             {'key': 'bbox-west-long', 'value': '-1.56001'},
#             {'key': 'contact-email', 'value': 'responde_icv@gva.es'},
#             {'key': 'coupled-resource', 'value': '[]'},
#             {'key': 'dataset-reference-date',
#              'value': '[{"type": "publication", "value": "2008-12-01"}]'},
#             {'key': 'frequency-of-update', 'value': ''},
#             {'key': 'graphic-preview-file',
# ...

# %%
# Suponiendo que 'result' es la variable que contiene los resultados de la API
for package in result['results']:
    # Buscar en el título del paquete
    if 'calidad del aire' in package['title'].lower():
        print('ghe')
        # También podrías buscar en los extras si es necesario
        for extra in package['extras']:
            if 'RVVCCA' in extra['value'].lower():
                print(f"Paquete encontrado: {package['title']}")
                # Aquí puedes manejar el paquete encontrado como necesites

# %%
# Figura 3 – Etiquetas de datos en dadesobertes.gva.es

import http.client

conn = http.client.HTTPSConnection("dadesobertes.gva.es")
payload = ''
headers = {
  'Cookie': 'NSC_mc1_qsf_usb_dlbo_80=ffffffffaf1398f045525d5f4f58455e445a4a423660'
}

# Hacer la petición HTTP.
conn.request("GET", "/api/3/action/tag_list", payload, headers)
response = conn.getresponse()

assert response.code == 200

# Usar el módulo JSON para cargar la respuesta de CKAN en un diccionario.
response_dict = json.loads(response.read())

# Comprobar el contenido de la respuesta.
assert response_dict['success'] is True
result = response_dict['result']
pprint.pprint(result)
# Out:
# ['1967',
#  '1975',
#  '1976',
#  '1980',
#  '1983',
#  '1987',
#  '1987-1988',
#  '1988',
#  '1989',
#  '1990',
#  '1992',
#  '1993',
#  '1994',
#  '1995',
#  '1996',
#  '1997',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2012',
#  '2014',
#  '2015',
#  '2016',
#  '2017',
#  '2018',
#  '2019',
#  '2020',
#  'actividad del establecimiento',
#  'actividades recreativas',
#  'ACTIVIDADES Y PRODUCTOS HUMANOS, EFECTOS SOBRE EL ',
#  'actividad laboral',
#  'ACTUACION ADMINISTRATIVA',
#  'acuifero',
#  'Administración pública',
#  'Agricultura En General',
#  'AGRICULTURA, SILVICULTURA Y PESCA',
#  'AGRICULTURE',
#  'Aguas',
#  'aguas continentales',
#  'aguas marinas',
#  'Aguas subterráneas',
#  'Albergues',
#  'Albufera',
#  'Alcoy',
#  'Alicante',
#  'Alquiler',
#  'altas',
#  'Alto Turia',
#  'alumnado',
#  'ambiente construido',
#  'ambientes marinos',
#  'ámbito',
#  'Aneo III',
#  'Anexo I',
#  'ANEXO I',
#  'Anexo II',
# ...

# %%
# Figura 4 – Detalles de un dataset

import http.client

conn = http.client.HTTPSConnection("dadesobertes.gva.es")
payload = ''
headers = {
  'Cookie': 'NSC_mc1_qsf_usb_dlbo_80=ffffffffaf1398f045525d5f4f58455e445a4a423660'
}

# Hacer la petición HTTP.
conn.request("GET", "/api/3/action/package_show?id=arcillas-medias-y-arenas", payload, headers)
response = conn.getresponse()

assert response.code == 200

# Usar el módulo JSON para cargar la respuesta de CKAN en un diccionario.
response_dict = json.loads(response.read())

# Comprobar el contenido de la respuesta.
assert response_dict['success'] is True
result = response_dict['result']
pprint.pprint(result)
# Out:
# {'archiver': {'is_broken': False,
#               'reason': '',
#               'status': 'Archived successfully',
#               'status_id': 0},
#  'creator_user_id': 'e3846494-e111-48e9-adeb-c27b3e75dc41',
#  'extras': [{'key': 'access_constraints',
#              'value': '["Sin limitaciones al acceso p\\u00fablico El formato '
#                       'nativo s\\u00f3lo se utiliza como fuente de datos, no '
#                       'se suministra."]'},
#             {'key': 'bbox-east-long', 'value': '0.473'},
#             {'key': 'bbox-north-lat', 'value': '40.765'},
#             {'key': 'bbox-south-lat', 'value': '37.905'},
#             {'key': 'bbox-west-long', 'value': '-1.334'},
#             {'key': 'contact-email', 'value': ''},
#             {'key': 'coupled-resource', 'value': '[]'},
#             {'key': 'dataset-reference-date',
#              'value': '[{"type": "publication", "value": "1994-01-01"}, '
# ...

# %%
# Figura 5 – Detalles de un grupo de los conjuntos de datos en dadesobertes.gva.es

import http.client

conn = http.client.HTTPSConnection("dadesobertes.gva.es")
payload = ''
headers = {
  'Cookie': 'NSC_mc1_qsf_usb_dlbo_80=ffffffffaf1398f045525d5f4f58455e445a4a423660'
}

# Hacer la petición HTTP.
conn.request("GET", "/api/3/action/group_show?id=medio-ambiente", payload, headers)
response = conn.getresponse()

assert response.code == 200

# Usar el módulo JSON para cargar la respuesta de CKAN en un diccionario.
response_dict = json.loads(response.read())

# Comprobar el contenido de la respuesta.
assert response_dict['success'] is True
result = response_dict['result']
pprint.pprint(result)
# Out:
# {'approval_status': 'approved',
#  'created': '2019-05-16T09:40:32.033344',
#  'description': '',
#  'display_name': 'Medio ambiente',
#  'extras': [],
#  'groups': [],
#  'id': 'a3fbb015-cf22-4ebe-b4c3-84590c9e3143',
#  'image_display_url': 'https://dadesobertes.gva.es/uploads/group/2020-02-10-074157.332364icmedioambientev1.png',
#  'image_url': '2020-02-10-074157.332364icmedioambientev1.png',
#  'is_organization': False,
#  'name': 'medio-ambiente',
#  'num_followers': 0,
#  'package_count': 853,
#  'revision_id': 'c428c356-2132-4f20-a312-9f3d99f4faec',
#  'state': 'active',
#  'tags': [],
#  'title': 'Medio ambiente',
#  'type': 'group'}

# %%
# Figura 6 – Búsqueda de conjunto de datos en dadesobertes.gva.es

import http.client

conn = http.client.HTTPSConnection("dadesobertes.gva.es")
payload = ''
headers = {
  'Cookie': 'NSC_mc1_qsf_usb_dlbo_80=ffffffffaf1398f045525d5f4f58455e445a4a423660'
}

# Hacer la petición HTTP.
conn.request("GET", "/api/3/action/package_search?q=covid", payload, headers)
response = conn.getresponse()

assert response.code == 200

# Usar el módulo JSON para cargar la respuesta de CKAN en un diccionario.
response_dict = json.loads(response.read())

# Comprobar el contenido de la respuesta.
assert response_dict['success'] is True
result = response_dict['result']
pprint.pprint(result)
# Out:
# {'count': 51,
#  'facets': {},
#  'results': [{'author': '',
#               'author_email': '',
#               'creator_user_id': '5a6a49f3-7060-4269-99eb-b788f822c898',
#               'fecha_fin_datos': '',
#               'fecha_inicio_datos': '',
#               'frequency': 'diaria',
#               'geolocation': 'No',
#               'groups': [{'description': '',
#                           'display_name': 'Salud',
#                           'id': '0d0a698e-d33e-4f62-bd2b-cf352b453713',
#                           'image_display_url': 'https://dadesobertes.gva.es/uploads/group/2020-02-10-074225.245796icsaludv1.png',
#                           'name': 'salud',
#                           'title': 'Salud'}],
#               'id': '96543e29-b6dd-48d0-a43c-0d2df1a0fa6e',
#               'isopen': True,
#               'license_id': 'cc-by',
#               'license_title': 'Creative Commons Attribution',
# ...

# %%
# Figura 7 – Búsqueda de recursos en dadesobertes.gva.es

import http.client

conn = http.client.HTTPSConnection("dadesobertes.gva.es")
payload = ''
headers = {
  'Cookie': 'NSC_mc1_qsf_usb_dlbo_80=ffffffffaf1398f045525d5f4f58455e445a4a423660'
}

# Hacer la petición HTTP.
conn.request("GET", "/api/3/action/resource_search?query=name:valencia", payload, headers)
response = conn.getresponse()

assert response.code == 200

# Usar el módulo JSON para cargar la respuesta de CKAN en un diccionario.
response_dict = json.loads(response.read())

# Comprobar el contenido de la respuesta.
assert response_dict['success'] is True
result = response_dict['result']
pprint.pprint(result)
# Out:
# {'count': 262,
#  'results': [{'cache_last_updated': None,
#               'cache_url': None,
#               'created': '2020-03-25T13:51:44.880498',
#               'datastore_active': True,
#               'description': '',
#               'format': 'CSV',
#               'hash': '',
#               'id': 'fee29031-eeda-4c09-ab74-c8eab31786c2',
#               'last_modified': '2020-03-28T08:00:02.828059',
#               'mimetype': None,
#               'mimetype_inner': None,
#               'name': 'Cooperativas Valencianas 2020-02',
#               'package_id': '92670532-ee4e-4c90-bc4e-1f1c6d0b936f',
#               'position': 0,
#               'resource_type': None,
#               'revision_id': '784c8d64-d039-45a6-ba85-ccdc1c2fb5e7',
#               'size': 899500,
#               'state': 'active',
# ...

# %%
# Figura 8 – Lista de los conjuntos de datos modificados recientemente en dadesobertes.gva.es

import http.client

conn = http.client.HTTPSConnection("dadesobertes.gva.es")
payload = ''
headers = {
  'Cookie': 'NSC_mc1_qsf_usb_dlbo_80=ffffffffaf1398f045525d5f4f58455e445a4a423660'
}

# Hacer la petición HTTP.
conn.request("GET", "/api/3/action/recently_changed_packages_activity_list", payload, headers)
response = conn.getresponse()

assert response.code == 200

# Usar el módulo JSON para cargar la respuesta de CKAN en un diccionario.
response_dict = json.loads(response.read())

# Comprobar el contenido de la respuesta.
assert response_dict['success'] is True
result = response_dict['result']
pprint.pprint(result)
# Out:
# [{'activity_type': 'changed package',
#   'data': {'package': {'author': None,
#                        'author_email': None,
#                        'creator_user_id': '5a6a49f3-7060-4269-99eb-b788f822c898',
#                        'id': '131b5619-233d-4f2c-b13c-777f763bfef8',
#                        'license_id': 'cc-by',
#                        'maintainer': None,
#                        'maintainer_email': None,
#                        'metadata_created': '2021-05-04T09:12:52.746651',
#                        'metadata_modified': '2021-05-17T09:12:58.681088',
#                        'name': 'tra-erte-sol-2021-05',
#                        'notes': 'Datos acumulados por Autoridad Laboral y '
#                                 'sector de los ERTE solicitados.',
#                        'owner_org': '318dd96c-aab4-4fce-afdf-b0aca2676186',
#                        'private': False,
#                        'revision_id': '7f723dce-4098-49d1-ba1f-12f4e32137ef',
# ...
